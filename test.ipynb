# %%
from algorithms import partial_obs_search_bfs_version

# %%
start = [[0, 0, 0],
         [1, 0, 0],
         [1, 1, 0]] 

goal = [[0, 0, 0],
        [0, 0, 0],
        [0, 0, 2]] 
r = partial_obs_search_bfs_version(start, goal)
print(r)
# Out:
# None
